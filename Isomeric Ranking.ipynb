# %%
import pandas as pd
import numpy as np
import os

os.getcwd()
# Out:
# 'C:\\Users\\dabrahamsson\\Dropbox\\UCSF postdoc\\R01 non target analysis\\R01 30 samples'

# %%
df = pd.read_csv('formulas_30_Aolin.csv')
df.head()
# Out:
#       INPUT       FOUND_BY          DTXSID          PREFERRED_NAME  \
# 0  C10H10N2  Exact Formula   DTXSID3020916  1,5-Naphthalenediamine
# 1  C10H10N2  Exact Formula   DTXSID6044432  1,8-Naphthalenediamine
# 2  C10H10N2  Exact Formula   DTXSID4061121  2,3-Naphthalenediamine
# 3  C10H10N2  Exact Formula  DTXSID60195183       1-Benzylimidazole
# 4  C10H10N2  Exact Formula   DTXSID6025696  1,4-Naphthalenediamine
#
#   DATA_SOURCES NUMBER_OF_PUBMED_ARTICLES PUBCHEM_DATA_SOURCES CPDAT_COUNT
# 0          103                        33                  136           -
# 1           69                         9                  126           -
# 2           41                        70                  138           -
# 3           41                        61                  186           -
# 4           39                         -                   53           -

# %%
df
# Out:
#           INPUT       FOUND_BY          DTXSID  \
# 0      C10H10N2  Exact Formula   DTXSID3020916
# 1      C10H10N2  Exact Formula   DTXSID6044432
# 2      C10H10N2  Exact Formula   DTXSID4061121
# 3      C10H10N2  Exact Formula  DTXSID60195183
# 4      C10H10N2  Exact Formula   DTXSID6025696
# ...         ...            ...             ...
# 58383    C9H8O2  Exact Formula  DTXSID20742415
# 58384    C9H8O2  Exact Formula  DTXSID00787728
# 58385  C9HF17O2  Exact Formula   DTXSID8031863
# 58386  C9HF17O2  Exact Formula   DTXSID2065969
# 58387  C9HF17O2  Exact Formula  DTXSID10380042
#
#                                   PREFERRED_NAME DATA_SOURCES  \
# 0                         1,5-Naphthalenediamine          103
# 1                         1,8-Naphthalenediamine           69
# 2                         2,3-Naphthalenediamine           41
# 3                              1-Benzylimidazole           41
# 4                         1,4-Naphthalenediamine           39
# ...                                          ...          ...
# 58383          (Cyclopenta[b]pyran-2-yl)methanol            1
# 58384  6,6a-Dihydro-1aH-indeno[1,2-b]oxiren-6-ol            1
# 58385                     Perfluorononanoic acid          140
# 58386   Perfluoro-6-methylheptanecarboxylic acid           22
# 58387     Perfluoro-3,5,5-trimethylhexanoic acid            8
#
#       NUMBER_OF_PUBMED_ARTICLES PUBCHEM_DATA_SOURCES CPDAT_COUNT
# 0                            33                  136           -
# 1                             9                  126           -
# 2                            70                  138           -
# 3                            61                  186           -
# 4                             -                   53           -
# ...                         ...                  ...         ...
# 58383                         -                    9           -
# 58384                         -                    4           -
# 58385                        16                   94           -
# 58386                         -                   18           -
# 58387                         -                   28           -
#
# [58388 rows x 8 columns]

# %%
df = df.loc[df['FOUND_BY'] != 'NO_MATCH']

# %%
df
# Out:
#           INPUT       FOUND_BY          DTXSID  \
# 0      C10H10N2  Exact Formula   DTXSID3020916
# 1      C10H10N2  Exact Formula   DTXSID6044432
# 2      C10H10N2  Exact Formula   DTXSID4061121
# 3      C10H10N2  Exact Formula  DTXSID60195183
# 4      C10H10N2  Exact Formula   DTXSID6025696
# ...         ...            ...             ...
# 58383    C9H8O2  Exact Formula  DTXSID20742415
# 58384    C9H8O2  Exact Formula  DTXSID00787728
# 58385  C9HF17O2  Exact Formula   DTXSID8031863
# 58386  C9HF17O2  Exact Formula   DTXSID2065969
# 58387  C9HF17O2  Exact Formula  DTXSID10380042
#
#                                   PREFERRED_NAME DATA_SOURCES  \
# 0                         1,5-Naphthalenediamine          103
# 1                         1,8-Naphthalenediamine           69
# 2                         2,3-Naphthalenediamine           41
# 3                              1-Benzylimidazole           41
# 4                         1,4-Naphthalenediamine           39
# ...                                          ...          ...
# 58383          (Cyclopenta[b]pyran-2-yl)methanol            1
# 58384  6,6a-Dihydro-1aH-indeno[1,2-b]oxiren-6-ol            1
# 58385                     Perfluorononanoic acid          140
# 58386   Perfluoro-6-methylheptanecarboxylic acid           22
# 58387     Perfluoro-3,5,5-trimethylhexanoic acid            8
#
#       NUMBER_OF_PUBMED_ARTICLES PUBCHEM_DATA_SOURCES CPDAT_COUNT
# 0                            33                  136           -
# 1                             9                  126           -
# 2                            70                  138           -
# 3                            61                  186           -
# 4                             -                   53           -
# ...                         ...                  ...         ...
# 58383                         -                    9           -
# 58384                         -                    4           -
# 58385                        16                   94           -
# 58386                         -                   18           -
# 58387                         -                   28           -
#
# [58387 rows x 8 columns]

# %%
df['DATA_SOURCES'] = df['DATA_SOURCES'].replace('-', '')
df['NUMBER_OF_PUBMED_ARTICLES'] = df['NUMBER_OF_PUBMED_ARTICLES'].replace('-', '')
df['PUBCHEM_DATA_SOURCES'] = df['PUBCHEM_DATA_SOURCES'].replace('-', '')
df['CPDAT_COUNT'] = df['CPDAT_COUNT'].replace('-', '')

#df['DATA_SOURCES'] = df['DATA_SOURCES'].str.extract('(\d+)', expand=False)
df['NUMBER_OF_PUBMED_ARTICLES'] = df['NUMBER_OF_PUBMED_ARTICLES'].str.extract('(\d+)', expand=False)
df['PUBCHEM_DATA_SOURCES'] = df['PUBCHEM_DATA_SOURCES'].str.extract('(\d+)', expand=False)
df['CPDAT_COUNT'] = df['CPDAT_COUNT'].str.extract('(\d+)', expand=False)

df['DATA_SOURCES'] = df['DATA_SOURCES'].astype(float)
df['NUMBER_OF_PUBMED_ARTICLES'] = df['NUMBER_OF_PUBMED_ARTICLES'].astype(float)
df['PUBCHEM_DATA_SOURCES'] = df['PUBCHEM_DATA_SOURCES'].astype(float)
df['CPDAT_COUNT'] = df['CPDAT_COUNT'].astype(float)
# Out:
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\dabrahamsson\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DF=df

DF=df.reset_index()

# %%
DF
DF = DF.fillna(1)

# %%
group=DF.groupby(['INPUT'])

# %%
def ratio(dataframe):
    isomer_count=dataframe.DTXSID.count()
    ratio=1/isomer_count
    dataframe['Blind_Probability']=ratio
    return(dataframe['Blind_Probability'])

def data(DF):
    data_ratio = DF['DATA_SOURCES']/DF.DATA_SOURCES.sum()
    DF['DATA_RATIO']=data_ratio
    return(DF['DATA_RATIO'])

def pubmed(DF):
    PUBMED_RATIO=DF['NUMBER_OF_PUBMED_ARTICLES'].divide(DF.NUMBER_OF_PUBMED_ARTICLES.sum(),fill_value=0)
    DF['PUBMED_RATIO']=PUBMED_RATIO
    return(DF['PUBMED_RATIO'])

def pubchem(DF):
    PUBCHEM_RATIO=DF['PUBCHEM_DATA_SOURCES'].divide(DF.PUBCHEM_DATA_SOURCES.sum(),fill_value=0)
    DF['PUBCHEM_RATIO']=PUBCHEM_RATIO
    return (DF['PUBCHEM_RATIO'])

def CPDAT(DF):
    CPDAT_RATIO=DF['CPDAT_COUNT'].divide(DF.CPDAT_COUNT.sum(),fill_value=0)
    DF['CPDAT_RATIO']=CPDAT_RATIO
    return (DF['CPDAT_RATIO'])

# %%
blind=pd.DataFrame(group.apply(ratio))

data_ratio = pd.DataFrame(group.apply(data))

pubmed = pd.DataFrame(group.apply(pubmed))

pubchem = pd.DataFrame(group.apply(pubchem))

CPDAT = pd.DataFrame(group.apply(CPDAT))

# %%
concat = pd.concat([blind,data_ratio,pubmed,pubchem,CPDAT],axis=1)

#concat1 = concat.droplevel(1)

#concat2=concat1.reset_index()

# %%
concat
# Out:
#                 Blind_Probability  DATA_RATIO  PUBMED_RATIO  PUBCHEM_RATIO  \
# INPUT
# C10H10N2 0               0.005682    0.093807      0.090164       0.018651
#          1               0.005682    0.062842      0.024590       0.017279
#          2               0.005682    0.037341      0.191257       0.018925
#          3               0.005682    0.037341      0.166667       0.025507
#          4               0.005682    0.035519      0.002732       0.007268
# ...                           ...         ...           ...            ...
# C9H9NO4  41955           0.005376    0.000921      0.002004       0.000432
#          41956           0.005376    0.000921      0.002004       0.000576
# C9HF17O2 58384           0.333333    0.823529      0.888889       0.671429
#          58385           0.333333    0.129412      0.055556       0.128571
#          58386           0.333333    0.047059      0.055556       0.200000
#
#                 CPDAT_RATIO
# INPUT
# C10H10N2 0         0.005682
#          1         0.005682
#          2         0.005682
#          3         0.005682
#          4         0.005682
# ...                     ...
# C9H9NO4  41955     0.005376
#          41956     0.005376
# C9HF17O2 58384     0.333333
#          58385     0.333333
#          58386     0.333333
#
# [58387 rows x 5 columns]

# %%
concat_test = concat.reset_index(level=0,inplace=True)
concat_test2 = concat.reset_index(level=0,inplace=True)

# %%
concat2 = concat.fillna(0)

# %%
concat2
# Out:
#        index     INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  \
# 0          0  C10H10N2           0.005682    0.093807      0.090164
# 1          1  C10H10N2           0.005682    0.062842      0.024590
# 2          2  C10H10N2           0.005682    0.037341      0.191257
# 3          3  C10H10N2           0.005682    0.037341      0.166667
# 4          4  C10H10N2           0.005682    0.035519      0.002732
# ...      ...       ...                ...         ...           ...
# 58382  41955   C9H9NO4           0.005376    0.000921      0.002004
# 58383  41956   C9H9NO4           0.005376    0.000921      0.002004
# 58384  58384  C9HF17O2           0.333333    0.823529      0.888889
# 58385  58385  C9HF17O2           0.333333    0.129412      0.055556
# 58386  58386  C9HF17O2           0.333333    0.047059      0.055556
#
#        PUBCHEM_RATIO  CPDAT_RATIO
# 0           0.018651     0.005682
# 1           0.017279     0.005682
# 2           0.018925     0.005682
# 3           0.025507     0.005682
# 4           0.007268     0.005682
# ...              ...          ...
# 58382       0.000432     0.005376
# 58383       0.000576     0.005376
# 58384       0.671429     0.333333
# 58385       0.128571     0.333333
# 58386       0.200000     0.333333
#
# [58387 rows x 7 columns]

# %%
concat2['AVERAGE'] = (concat2['DATA_RATIO'].add(concat2['PUBMED_RATIO']).add(concat2['PUBCHEM_RATIO']).add(concat2['CPDAT_RATIO']))/4

concat2['SCORE']= concat2[['AVERAGE','Blind_Probability']].mean(axis=1)

concat2
#concat4=concat3.reset_index()
# Out:
#        index     INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  \
# 0          0  C10H10N2           0.005682    0.093807      0.090164
# 1          1  C10H10N2           0.005682    0.062842      0.024590
# 2          2  C10H10N2           0.005682    0.037341      0.191257
# 3          3  C10H10N2           0.005682    0.037341      0.166667
# 4          4  C10H10N2           0.005682    0.035519      0.002732
# ...      ...       ...                ...         ...           ...
# 58382  41955   C9H9NO4           0.005376    0.000921      0.002004
# 58383  41956   C9H9NO4           0.005376    0.000921      0.002004
# 58384  58384  C9HF17O2           0.333333    0.823529      0.888889
# 58385  58385  C9HF17O2           0.333333    0.129412      0.055556
# 58386  58386  C9HF17O2           0.333333    0.047059      0.055556
#
#        PUBCHEM_RATIO  CPDAT_RATIO   AVERAGE     SCORE
# 0           0.018651     0.005682  0.052076  0.028879
# 1           0.017279     0.005682  0.027598  0.016640
# 2           0.018925     0.005682  0.063301  0.034491
# 3           0.025507     0.005682  0.058799  0.032240
# 4           0.007268     0.005682  0.012800  0.009241
# ...              ...          ...       ...       ...
# 58382       0.000432     0.005376  0.002183  0.003780
# 58383       0.000576     0.005376  0.002219  0.003798
# 58384       0.671429     0.333333  0.679295  0.506314
# 58385       0.128571     0.333333  0.161718  0.247526
# 58386       0.200000     0.333333  0.158987  0.246160
#
# [58387 rows x 9 columns]

# %%
concat3=concat2.set_index('index')
concat3
# Out:
#           INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  PUBCHEM_RATIO  \
# index
# 0      C10H10N2           0.005682    0.093807      0.090164       0.018651
# 1      C10H10N2           0.005682    0.062842      0.024590       0.017279
# 2      C10H10N2           0.005682    0.037341      0.191257       0.018925
# 3      C10H10N2           0.005682    0.037341      0.166667       0.025507
# 4      C10H10N2           0.005682    0.035519      0.002732       0.007268
# ...         ...                ...         ...           ...            ...
# 41955   C9H9NO4           0.005376    0.000921      0.002004       0.000432
# 41956   C9H9NO4           0.005376    0.000921      0.002004       0.000576
# 58384  C9HF17O2           0.333333    0.823529      0.888889       0.671429
# 58385  C9HF17O2           0.333333    0.129412      0.055556       0.128571
# 58386  C9HF17O2           0.333333    0.047059      0.055556       0.200000
#
#        CPDAT_RATIO   AVERAGE     SCORE
# index
# 0         0.005682  0.052076  0.028879
# 1         0.005682  0.027598  0.016640
# 2         0.005682  0.063301  0.034491
# 3         0.005682  0.058799  0.032240
# 4         0.005682  0.012800  0.009241
# ...            ...       ...       ...
# 41955     0.005376  0.002183  0.003780
# 41956     0.005376  0.002219  0.003798
# 58384     0.333333  0.679295  0.506314
# 58385     0.333333  0.161718  0.247526
# 58386     0.333333  0.158987  0.246160
#
# [58387 rows x 8 columns]

# %%
concat3['DTXSID']= DF['DTXSID']
concat3['PREFERRED_NAME']= DF['PREFERRED_NAME']
concat3
# Out:
#           INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  PUBCHEM_RATIO  \
# index
# 0      C10H10N2           0.005682    0.093807      0.090164       0.018651
# 1      C10H10N2           0.005682    0.062842      0.024590       0.017279
# 2      C10H10N2           0.005682    0.037341      0.191257       0.018925
# 3      C10H10N2           0.005682    0.037341      0.166667       0.025507
# 4      C10H10N2           0.005682    0.035519      0.002732       0.007268
# ...         ...                ...         ...           ...            ...
# 41955   C9H9NO4           0.005376    0.000921      0.002004       0.000432
# 41956   C9H9NO4           0.005376    0.000921      0.002004       0.000576
# 58384  C9HF17O2           0.333333    0.823529      0.888889       0.671429
# 58385  C9HF17O2           0.333333    0.129412      0.055556       0.128571
# 58386  C9HF17O2           0.333333    0.047059      0.055556       0.200000
#
#        CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# index
# 0         0.005682  0.052076  0.028879   DTXSID3020916
# 1         0.005682  0.027598  0.016640   DTXSID6044432
# 2         0.005682  0.063301  0.034491   DTXSID4061121
# 3         0.005682  0.058799  0.032240  DTXSID60195183
# 4         0.005682  0.012800  0.009241   DTXSID6025696
# ...            ...       ...       ...             ...
# 41955     0.005376  0.002183  0.003780  DTXSID90835666
# 41956     0.005376  0.002219  0.003798  DTXSID50850315
# 58384     0.333333  0.679295  0.506314   DTXSID8031863
# 58385     0.333333  0.161718  0.247526   DTXSID2065969
# 58386     0.333333  0.158987  0.246160  DTXSID10380042
#
#                                           PREFERRED_NAME
# index
# 0                                 1,5-Naphthalenediamine
# 1                                 1,8-Naphthalenediamine
# 2                                 2,3-Naphthalenediamine
# 3                                      1-Benzylimidazole
# 4                                 1,4-Naphthalenediamine
# ...                                                  ...
# 41955  Ethyl 5-cyano-2-(hydroxymethylidene)-3-oxopent...
# 41956  2-Hydroxy-3,4-dimethyl-5,6-dioxocyclohexa-1,3-...
# 58384                             Perfluorononanoic acid
# 58385           Perfluoro-6-methylheptanecarboxylic acid
# 58386             Perfluoro-3,5,5-trimethylhexanoic acid
#
# [58387 rows x 10 columns]

# %%
concat3['abc']=concat3.index
concat3
# Out:
#           INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  PUBCHEM_RATIO  \
# index
# 0      C10H10N2           0.005682    0.093807      0.090164       0.018651
# 1      C10H10N2           0.005682    0.062842      0.024590       0.017279
# 2      C10H10N2           0.005682    0.037341      0.191257       0.018925
# 3      C10H10N2           0.005682    0.037341      0.166667       0.025507
# 4      C10H10N2           0.005682    0.035519      0.002732       0.007268
# ...         ...                ...         ...           ...            ...
# 41955   C9H9NO4           0.005376    0.000921      0.002004       0.000432
# 41956   C9H9NO4           0.005376    0.000921      0.002004       0.000576
# 58384  C9HF17O2           0.333333    0.823529      0.888889       0.671429
# 58385  C9HF17O2           0.333333    0.129412      0.055556       0.128571
# 58386  C9HF17O2           0.333333    0.047059      0.055556       0.200000
#
#        CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# index
# 0         0.005682  0.052076  0.028879   DTXSID3020916
# 1         0.005682  0.027598  0.016640   DTXSID6044432
# 2         0.005682  0.063301  0.034491   DTXSID4061121
# 3         0.005682  0.058799  0.032240  DTXSID60195183
# 4         0.005682  0.012800  0.009241   DTXSID6025696
# ...            ...       ...       ...             ...
# 41955     0.005376  0.002183  0.003780  DTXSID90835666
# 41956     0.005376  0.002219  0.003798  DTXSID50850315
# 58384     0.333333  0.679295  0.506314   DTXSID8031863
# 58385     0.333333  0.161718  0.247526   DTXSID2065969
# 58386     0.333333  0.158987  0.246160  DTXSID10380042
#
#                                           PREFERRED_NAME    abc
# index
# 0                                 1,5-Naphthalenediamine      0
# 1                                 1,8-Naphthalenediamine      1
# 2                                 2,3-Naphthalenediamine      2
# 3                                      1-Benzylimidazole      3
# 4                                 1,4-Naphthalenediamine      4
# ...                                                  ...    ...
# 41955  Ethyl 5-cyano-2-(hydroxymethylidene)-3-oxopent...  41955
# 41956  2-Hydroxy-3,4-dimethyl-5,6-dioxocyclohexa-1,3-...  41956
# 58384                             Perfluorononanoic acid  58384
# 58385           Perfluoro-6-methylheptanecarboxylic acid  58385
# 58386             Perfluoro-3,5,5-trimethylhexanoic acid  58386
#
# [58387 rows x 11 columns]

# %%
#concat_grouped = concat3.groupby('INPUT').max()
concat4 = concat3.sort_values('SCORE', ascending=False).drop_duplicates('INPUT')
concat4
# Out:
#             INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  PUBCHEM_RATIO  \
# index
# 45892   C12HF23O2           1.000000    1.000000      1.000000       1.000000
# 30116     C37H77N           1.000000    1.000000      1.000000       1.000000
# 30013  C27H48N2O3           1.000000    1.000000      1.000000       1.000000
# 51694  C26H42N4O2           1.000000    1.000000      1.000000       1.000000
# 29896   C25H48O10           1.000000    1.000000      1.000000       1.000000
# ...           ...                ...         ...           ...            ...
# 55239     C8H14O3           0.003125    0.049094      0.003049       0.017371
# 18897   C13H19NO2           0.003215    0.038393      0.006079       0.024321
# 8746     C11H14O4           0.003663    0.031943      0.003650       0.019268
# 13204     C12H16O           0.003344    0.024242      0.003322       0.007898
# 4766     C10H16O3           0.003690    0.010025      0.025180       0.009171
#
#        CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# index
# 45892     1.000000  1.000000  1.000000   DTXSID8031861
# 30116     1.000000  1.000000  1.000000   DTXSID6027559
# 30013     1.000000  1.000000  1.000000   DTXSID1044778
# 51694     1.000000  1.000000  1.000000   DTXSID3068417
# 29896     1.000000  1.000000  1.000000   DTXSID4070324
# ...            ...       ...       ...             ...
# 55239     0.003125  0.018160  0.010642   DTXSID8026729
# 18897     0.003215  0.018002  0.010609   DTXSID9045899
# 8746      0.003650  0.014628  0.009145   DTXSID7022257
# 13204     0.022876  0.014585  0.008964   DTXSID6074883
# 4766      0.003690  0.012016  0.007853  DTXSID20198271
#
#                                           PREFERRED_NAME    abc
# index
# 45892                           Perfluorododecanoic acid  45892
# 30116                               Distearylmethylamine  30116
# 30013  1-(1-Acetyl-2,2,6,6-tetramethylpiperidin-4-yl)...  30013
# 51694  N,N'-Bis(2,2,6,6-tetramethyl-4-piperidyl)isoph...  51694
# 29896  Bis(2-(2-(2-butoxyethoxy)ethoxy)ethyl) hydroge...  29896
# ...                                                  ...    ...
# 55239                                 Butanoic anhydride  55239
# 18897                                          Exalamide  18897
# 8746                     2',3',4'-Trimethoxyacetophenone   8746
# 13204                Benzenepropanal, 4-(1-methylethyl)-  13204
# 4766                                     Oleuropeic acid   4766
#
# [556 rows x 11 columns]

# %%
concat5=concat4.reset_index().set_index('abc')
concat5
# Out:
#        index       INPUT  Blind_Probability  DATA_RATIO  PUBMED_RATIO  \
# abc
# 45892  45892   C12HF23O2           1.000000    1.000000      1.000000
# 30116  30116     C37H77N           1.000000    1.000000      1.000000
# 30013  30013  C27H48N2O3           1.000000    1.000000      1.000000
# 51694  51694  C26H42N4O2           1.000000    1.000000      1.000000
# 29896  29896   C25H48O10           1.000000    1.000000      1.000000
# ...      ...         ...                ...         ...           ...
# 55239  55239     C8H14O3           0.003125    0.049094      0.003049
# 18897  18897   C13H19NO2           0.003215    0.038393      0.006079
# 8746    8746    C11H14O4           0.003663    0.031943      0.003650
# 13204  13204     C12H16O           0.003344    0.024242      0.003322
# 4766    4766    C10H16O3           0.003690    0.010025      0.025180
#
#        PUBCHEM_RATIO  CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# abc
# 45892       1.000000     1.000000  1.000000  1.000000   DTXSID8031861
# 30116       1.000000     1.000000  1.000000  1.000000   DTXSID6027559
# 30013       1.000000     1.000000  1.000000  1.000000   DTXSID1044778
# 51694       1.000000     1.000000  1.000000  1.000000   DTXSID3068417
# 29896       1.000000     1.000000  1.000000  1.000000   DTXSID4070324
# ...              ...          ...       ...       ...             ...
# 55239       0.017371     0.003125  0.018160  0.010642   DTXSID8026729
# 18897       0.024321     0.003215  0.018002  0.010609   DTXSID9045899
# 8746        0.019268     0.003650  0.014628  0.009145   DTXSID7022257
# 13204       0.007898     0.022876  0.014585  0.008964   DTXSID6074883
# 4766        0.009171     0.003690  0.012016  0.007853  DTXSID20198271
#
#                                           PREFERRED_NAME
# abc
# 45892                           Perfluorododecanoic acid
# 30116                               Distearylmethylamine
# 30013  1-(1-Acetyl-2,2,6,6-tetramethylpiperidin-4-yl)...
# 51694  N,N'-Bis(2,2,6,6-tetramethyl-4-piperidyl)isoph...
# 29896  Bis(2-(2-(2-butoxyethoxy)ethoxy)ethyl) hydroge...
# ...                                                  ...
# 55239                                 Butanoic anhydride
# 18897                                          Exalamide
# 8746                     2',3',4'-Trimethoxyacetophenone
# 13204                Benzenepropanal, 4-(1-methylethyl)-
# 4766                                     Oleuropeic acid
#
# [556 rows x 11 columns]

# %%
concat5.columns=concat5.columns.str.replace('INPUT', 'Formula')
concat5
# Out:
#        index     Formula  Blind_Probability  DATA_RATIO  PUBMED_RATIO  \
# abc
# 45892  45892   C12HF23O2           1.000000    1.000000      1.000000
# 30116  30116     C37H77N           1.000000    1.000000      1.000000
# 30013  30013  C27H48N2O3           1.000000    1.000000      1.000000
# 51694  51694  C26H42N4O2           1.000000    1.000000      1.000000
# 29896  29896   C25H48O10           1.000000    1.000000      1.000000
# ...      ...         ...                ...         ...           ...
# 55239  55239     C8H14O3           0.003125    0.049094      0.003049
# 18897  18897   C13H19NO2           0.003215    0.038393      0.006079
# 8746    8746    C11H14O4           0.003663    0.031943      0.003650
# 13204  13204     C12H16O           0.003344    0.024242      0.003322
# 4766    4766    C10H16O3           0.003690    0.010025      0.025180
#
#        PUBCHEM_RATIO  CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# abc
# 45892       1.000000     1.000000  1.000000  1.000000   DTXSID8031861
# 30116       1.000000     1.000000  1.000000  1.000000   DTXSID6027559
# 30013       1.000000     1.000000  1.000000  1.000000   DTXSID1044778
# 51694       1.000000     1.000000  1.000000  1.000000   DTXSID3068417
# 29896       1.000000     1.000000  1.000000  1.000000   DTXSID4070324
# ...              ...          ...       ...       ...             ...
# 55239       0.017371     0.003125  0.018160  0.010642   DTXSID8026729
# 18897       0.024321     0.003215  0.018002  0.010609   DTXSID9045899
# 8746        0.019268     0.003650  0.014628  0.009145   DTXSID7022257
# 13204       0.007898     0.022876  0.014585  0.008964   DTXSID6074883
# 4766        0.009171     0.003690  0.012016  0.007853  DTXSID20198271
#
#                                           PREFERRED_NAME
# abc
# 45892                           Perfluorododecanoic acid
# 30116                               Distearylmethylamine
# 30013  1-(1-Acetyl-2,2,6,6-tetramethylpiperidin-4-yl)...
# 51694  N,N'-Bis(2,2,6,6-tetramethyl-4-piperidyl)isoph...
# 29896  Bis(2-(2-(2-butoxyethoxy)ethoxy)ethyl) hydroge...
# ...                                                  ...
# 55239                                 Butanoic anhydride
# 18897                                          Exalamide
# 8746                     2',3',4'-Trimethoxyacetophenone
# 13204                Benzenepropanal, 4-(1-methylethyl)-
# 4766                                     Oleuropeic acid
#
# [556 rows x 11 columns]

# %%
concat5.to_csv('Aiolin_prioritized_isomers.csv')

# %%
df = pd.read_csv('Level 3 annotations.csv')

# %%
dfm = pd.merge(concat5, df, on='Formula', how='right')

# %%
dfm
# Out:
#         index        Formula  Blind_Probability  DATA_RATIO  PUBMED_RATIO  \
# 0     45892.0      C12HF23O2            1.00000    1.000000       1.00000
# 1     30116.0        C37H77N            1.00000    1.000000       1.00000
# 2     30013.0     C27H48N2O3            1.00000    1.000000       1.00000
# 3     51694.0     C26H42N4O2            1.00000    1.000000       1.00000
# 4     29896.0      C25H48O10            1.00000    1.000000       1.00000
# ...       ...            ...                ...         ...           ...
# 1445   4766.0       C10H16O3            0.00369    0.010025       0.02518
# 1446   4766.0       C10H16O3            0.00369    0.010025       0.02518
# 1447   4766.0       C10H16O3            0.00369    0.010025       0.02518
# 1448   4766.0       C10H16O3            0.00369    0.010025       0.02518
# 1449      NaN  C21H15F27N2O3                NaN         NaN           NaN
#
#       PUBCHEM_RATIO  CPDAT_RATIO   AVERAGE     SCORE          DTXSID  \
# 0          1.000000      1.00000  1.000000  1.000000   DTXSID8031861
# 1          1.000000      1.00000  1.000000  1.000000   DTXSID6027559
# 2          1.000000      1.00000  1.000000  1.000000   DTXSID1044778
# 3          1.000000      1.00000  1.000000  1.000000   DTXSID3068417
# 4          1.000000      1.00000  1.000000  1.000000   DTXSID4070324
# ...             ...          ...       ...       ...             ...
# 1445       0.009171      0.00369  0.012016  0.007853  DTXSID20198271
# 1446       0.009171      0.00369  0.012016  0.007853  DTXSID20198271
# 1447       0.009171      0.00369  0.012016  0.007853  DTXSID20198271
# 1448       0.009171      0.00369  0.012016  0.007853  DTXSID20198271
# 1449            NaN          NaN       NaN       NaN             NaN
#
#                                          PREFERRED_NAME  \
# 0                              Perfluorododecanoic acid
# 1                                  Distearylmethylamine
# 2     1-(1-Acetyl-2,2,6,6-tetramethylpiperidin-4-yl)...
# 3     N,N'-Bis(2,2,6,6-tetramethyl-4-piperidyl)isoph...
# 4     Bis(2-(2-(2-butoxyethoxy)ethoxy)ethyl) hydroge...
# ...                                                 ...
# 1445                                    Oleuropeic acid
# 1446                                    Oleuropeic acid
# 1447                                    Oleuropeic acid
# 1448                                    Oleuropeic acid
# 1449                                                NaN
#
#                      chemID_RT
# 0         [-]C12HF23O2, 13.249
# 1           [+]C37H77N, 16.763
# 2        [+]C27H48N2O3, 12.348
# 3        [-]C26H42N4O2, 15.815
# 4         [+]C25H48O10, 13.435
# ...                        ...
# 1445         [-]C10H16O3, 5.78
# 1446        [-]C10H16O3, 6.564
# 1447        [-]C10H16O3, 7.342
# 1448        [-]C10H16O3, 9.624
# 1449  [+]C21H15F27N2O3, 13.993
#
# [1450 rows x 12 columns]

# %%
dfm.to_csv('Aolin_Level3_annotations.csv')
